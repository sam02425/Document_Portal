# %%
print("all ok")
# Out:
# all ok

# %%
import os
import logging
from datetime import datetime

# %%
os.getcwd()
# Out:
# '/home/currycreations/Desktop/New Folder/Document_Portal/notebook'

# %%
logs_dir = os.path.join(os.getcwd(), "logs")
os.makedirs(logs_dir, exist_ok=True)

# %%
LOG_FILE = f"{logs_dir}/log_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log"

# %%
LOG_FILE
# Out:
# '/home/currycreations/Desktop/New Folder/Document_Portal/notebook/logs/log_20251224_163804.log'

# %%
LOG_FILE_PATH=os.path.join(logs_dir, LOG_FILE)

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    level=logging.INFO,
    format="[ %(asctime)s ] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
)

# %%
logger=logging.getLogger("DocumentPortal")

# %%
logger.info("This is an info message")

# %%
import structlog
log=structlog.get_logger()

# %%
log.info("User uploaded a file", user_id=123, filename="report.pdf")
# Out:
# 2025-12-24 16:41:33 [info     ] User uploaded a file           filename=report.pdf user_id=123

# %%
log.error("File upload failed", user_id=123, filename="report.pdf", error="Network error")
# Out:
# 2025-12-24 16:42:32 [error    ] File upload failed             error='Network error' filename=report.pdf user_id=123
